# %%
import tkinter
from tkinter.ttk import *
from tkinter import filedialog
import pandas as pd
import numpy as np

# %%
# !python3.7 -m pip install --upgrade pip

# %%
# !pip install

# %%
# import PySimpleGUI as sg
# sg.SetOptions(button_color=sg.COLOR_SYSTEM_DEFAULT)

# %%
window = tkinter.Tk()
window.title('Drilling Simulation and Real-Time Optimization Platform')
window.geometry('1200x700')
window.resizable(0,0)

#========================================
# icon = tkinter.PhotoImage(file="okstate_Logo.png")
# label = tkinter.Label(window, image=icon).pack()

#========================================
L1 = tkinter.Label(window, 
                   text = '',
                   font=('Arial Bold', 10))
L1.grid(column=1,row=0)


def clicked():
    
    import_file_path = filedialog.askopenfilename()
    df = pd.read_csv(import_file_path)
    L1.configure(text='Data Operational parameters Uploaded!', width=50,height=1)
#     L1.configure(text='Address is '+ import_file_path, 
#                  width=50,height=1,font=('Arial Bold', 8))
    
    
    

bt1 = tkinter.Button(window, 
                    text="Upload Operational parameters",
                    fg='white',
                    bg='purple',
                    font=('Arial Bold', 15),
                    command=clicked, width=40,height=2)
bt1.grid(column=0,row=0)

#========================================
L2 = tkinter.Label(window, 
                   text = '',
                   font=('Arial Bold', 10))
L2.grid(column=1,row=2)

def clicked2():
    import_file_path = filedialog.askopenfilename()
    df = pd.read_csv(import_file_path)
    L2.configure(text='Data bit details Uploaded!', width=50,height=1)

bt2 = tkinter.Button(window, 
                    text="Upload bit details",
                    fg='white',
                    bg='purple',
                    font=('Arial Bold', 15),
                    command=clicked2, width=40,height=2)
bt2.grid(column=0,row=2)

#========================================
L3 = tkinter.Label(window, 
                   text = '',
                   font=('Arial Bold', 10))
L3.grid(column=1,row=3)

def clicked3():
    import_file_path = filedialog.askopenfilename()
    df = pd.read_csv(import_file_path)
    L3.configure(text='Data Temperature properties Uploaded!', width=50,height=1)

bt3 = tkinter.Button(window, 
                    text="Upload temperature properties",
                    fg='white',
                    bg='purple',
                    font=('Arial Bold', 15),
                    command=clicked3, width=40,height=2)
bt3.grid(column=0,row=3)





#========================================
L4 = tkinter.Label(window, 
                   text = '',
                   font=('Arial Bold', 10))
L4.grid(column=1,row=4)

def clicked4():
    L4.configure(text='The Simulator is Running...!', width=50,height=1)

bt4 = tkinter.Button(window, 
                    text="STEP1: Run initial Analysis",
                    fg='white',
                    bg='green',
                    font=('Arial Bold', 15),
                    command=clicked4, width=40,height=2)
bt4.grid(column=0,row=4)



#========================================
L5 = tkinter.Label(window, 
                   text = '',
                   font=('Arial Bold', 10))
L5.grid(column=1,row=5)

def clicked5():
    L5.configure(text='Real-time UCS was calculated.!', width=50,height=1)

bt5 = tkinter.Button(window, 
                    text="STEP2: Run UCS_realtime Analysis",
                    fg='white',
                    bg='green',
                    font=('Arial Bold', 15),
                    command=clicked5, width=40,height=2)
bt5.grid(column=0,row=5)


#========================================
L6 = tkinter.Label(window, 
                   text = '',
                   font=('Arial Bold', 10))
L6.grid(column=1,row=6)

def clicked6():
    L6.configure(text='Optimum Realtime Analysis done!', width=50,height=1)

bt6 = tkinter.Button(window, 
                    text="STEP3: Run Optimum Real-time Analysis",
                    fg='white',
                    bg='green',
                    font=('Arial Bold', 15),
                    command=clicked6, width=40,height=2)
bt6.grid(column=0,row=6)



#========================================
# L4 = tkinter.Label(window, 
#                    text = '',
#                    font=('Arial Bold', 10))
# L4.grid(column=1,row=4)

# def clicked2():
#     L4.configure(text='Output file Saved!', width=50,height=1)

# bt4 = tkinter.Button(window, 
#                     text="Save output file",
#                     fg='white',
#                     bg='green',
#                     command=clicked2, width=30,height=1)
# bt4.grid(column=0,row=4)




# #========================================

# rad1 = Radiobutton(window, text='PDC ROP Model#1', value=1)
# rad2 = Radiobutton(window, text='PDC ROP Model#2', value=2)
# rad3 = Radiobutton(window, text='PDC ROP Model#3', value=3)
# rad1.grid(column=0,row=4)
# rad2.grid(column=1,row=4)
# rad3.grid(column=2,row=4)

# #========================================

# rad4 = Radiobutton(window, text='Glowka Temprature Model', value=1)
# rad5 = Radiobutton(window, text='New Temprature Model', value=2)
# rad4.grid(column=0,row=5)
# rad5.grid(column=1,row=5)

# #========================================

# rad6 = Radiobutton(window, text='Kerkar et al. Hydraulic Model', value=1)
# rad7 = Radiobutton(window, text='New Hydraulic Model', value=2)
# rad6.grid(column=0,row=6)
# rad7.grid(column=1,row=6)


window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\daslab hareland 3\appdata\local\programs\python\python36\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-5-f3e5fcef1445>", line 20, in clicked
#     df = pd.read_csv(import_file_path)
#   File "c:\users\daslab hareland 3\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py", line 676, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "c:\users\daslab hareland 3\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py", line 448, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "c:\users\daslab hareland 3\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py", line 880, in __init__
#     self._make_engine(self.engine)
# ...
